# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('bank-additional-full.csv')
data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41182   73      retired  married  professional.course       no     yes   no
# 41183   46  blue-collar  married  professional.course       no      no   no
# 41184   56      retired  married    university.degree       no     yes   no
# 41185   44   technician  married  professional.course       no      no   no
# 41186   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
a=data.job
for m in a:
    if m=='services':
        
    else:
        pass
data_day_yes = data[data.loan == 'yes']
data_day_yes_group = data_day_yes.groupby('day_of_week')
d = data_day_yes_group.loan.value_counts()
fig, ax = plt.subplots()
d.plot.bar()

# %%
b=data.job
for i in b:
    if i=='housemaid':
        data_day_yes = data[data.loan == 'yes']
        data_day_yes_group = data_day_yes.groupby('day_of_week')
        d = data_day_yes_group.loan.value_counts()
    else:
        pass

fig, ax = plt.subplots()
d.plot.bar()

# %%
a=data.groupby('job')['job','count','y'].sum()
a
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_18724\3093769287.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   a=data.groupby('job')['job','count','y'].sum()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\final project\code.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/final%20project/code.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> a=data.groupby('job')['job','count','y'].sum()
#       <a href='vscode-notebook-cell:/c%3A/final%20project/code.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> a
#
# File c:\conda\envs\ds\lib\site-packages\pandas\core\groupby\generic.py:1338, in DataFrameGroupBy.__getitem__(self, key)
#    1329 if isinstance(key, tuple) and len(key) > 1:
#    1330     # if len == 1, then it becomes a SeriesGroupBy and this is actually
# ...

# %%
if m=='services':
    data_day_yes = data[data.loan == 'yes']
    data_day_yes_group = data_day_yes.groupby('day_of_week')
    d = data_day_yes_group.loan.value_counts()

fig, ax = plt.subplots()
d.plot.bar()

# %%
if job1== 'admin.': 
    data_day_yes = data[data.loan == 'yes']
    data_day_yes_group = data_day_yes.groupby('day_of_week')
    d = data_day_yes_group.loan.value_counts()

# %%
data.job.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 41187 entries, 0 to 41186
# Series name: job
# Non-Null Count  Dtype
# --------------  -----
# 41187 non-null  object
# dtypes: object(1)
# memory usage: 321.9+ KB

# %%
from pyrsistent import v


bank_data=data.count()
bank_data
a=data.groupby('job')['job'].count()
b=data.groupby('marital')['marital'].count()
c=data.groupby('education')['education'].count()
d=data.groupby('default')['default'].count()
print(a)
print(b)
print(c)
print(d)
# Out:
# job
# admin.           10422
# blue-collar       9254
# entrepreneur      1456
# housemaid         1059
# management        2924
# retired           1720
# self-employed     1421
# services          3969
# student            875
# technician        6743
# unemployed        1014
# unknown            330
# Name: job, dtype: int64
# marital
# divorced     4612
# married     24928
# single      11567
# unknown        80
# Name: marital, dtype: int64
# education
# basic.4y                4176
# basic.6y                2292
# basic.9y                6045
# high.school             9515
# illiterate                18
# professional.course     5243
# university.degree      12167
# unknown                 1731
# Name: education, dtype: int64
# default
# no         32587
# unknown     8597
# yes            3
# Name: default, dtype: int64

# %%
data.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  41187.000000  41187.000000  41187.000000  41187.000000  41187.000000
# mean      40.024280    258.287591      2.567533    962.474567      0.172967
# std       10.421282    259.281868      2.770021    186.913090      0.494906
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    180.000000      2.000000    999.000000      0.000000
# 75%       47.000000    319.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m  nr.employed  \
# count  41187.000000    41187.000000   41187.000000  41187.000000  41187.00000
# mean       0.081914       93.575635     -40.502350      3.621354   5167.04085
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41187 entries, 0 to 41186
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41187 non-null  int64
#  1   job             41187 non-null  object
#  2   marital         41187 non-null  object
#  3   education       41187 non-null  object
#  4   default         41187 non-null  object
#  5   housing         41187 non-null  object
#  6   loan            41187 non-null  object
#  7   contact         41187 non-null  object
#  8   month           41187 non-null  object
#  9   day_of_week     41187 non-null  object
#  10  duration        41187 non-null  int64
#  11  campaign        41187 non-null  int64
#  12  pdays           41187 non-null  int64
#  13  previous        41187 non-null  int64
#  14  poutcome        41187 non-null  object
#  15  emp.var.rate    41187 non-null  float64
#  16  cons.price.idx  41187 non-null  float64
# ...

# %%
day=data.groupby('day_of_week')
d=day['y']

# %%
d=data[(data['y']=='yes')]
e=d['job','y']

# %%
data_copy=data.copy()
data["count"]=1
data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41182   73      retired  married  professional.course       no     yes   no
# 41183   46  blue-collar  married  professional.course       no      no   no
# 41184   56      retired  married    university.degree       no     yes   no
# 41185   44   technician  married  professional.course       no      no   no
# 41186   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
a=data.groupby('job')['job','count','y'].sum()
fig,ax = plt.subplots()
a.hist(
          )
fig.show()
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_18724\680965824.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   a=data.groupby('job')['job','count','y'].sum()
# C:\Users\1\AppData\Local\Temp\ipykernel_18724\680965824.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig,ax = plt.subplots(1,3,figsize=(15,5))
data.job.plot.box()

# %%
data.job.hist(figsize=(30,5))

# %%
data.groubpy('age')

# %%
fig, ax = plt.subplots()
a.hist(
           title="Distribution of jobs and deposit",
           labels={"x":"Jobs titles","y":"Number of clients","color":"deposit"})
fig.show()

# %%
data.job.value_counts()

# %%
job=data.groupby('job').sum()
job
# Out:
#                   age  duration  campaign    pdays  previous  emp.var.rate  \
# job
# admin.         397988   2650441     27342  9945915      1970         162.2
# blue-collar    366049   2448075     23676  9116674      1134        2304.2
# entrepreneur    60749    383318      3692  1428725       202         231.1
# housemaid       48199    265330      2793  1017215       146         460.5
# management     123869    751638      7240  2814780       541         -37.1
# retired        106687    470785      4260  1544450       563       -1201.1
# self-employed   56768    375346      3781  1387779       204         133.8
# services       150530   1025582     10271  3889517       615         696.0
# student         22658    248223      1841   735190       459       -1232.0
# technician     259657   1687316     17379  6503004      1037        1851.4
# unemployed      40290    252944      2600   948411       202        -113.3
# ...

# %%
job1 = st.sidebar.multiselect('job', data.job.unique(),data.job.unique())
st.map(job1)

# %%
fig, ax = plt.subplots(2,1)
data['cons.price.idx'].plot(ax=ax[0],figsize=(20,10)).set_xticks(df_country.index, df_country.country, rotation=60)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
data_education_yes_group = data.groupby(['cons.price.idx','y'],as_index=False)
d2 = data_education_yes_group.y.value_counts()
d2.plot(ax=ax,figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
df_t4=data.sort_values(by='cons.price.idx', ascending=False,ignore_index=True)
df_t4.data['cons.price.idx'].plot(ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\final project\code.ipynb Cell 24 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/final%20project/code.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> fig, ax = plt.subplots()
#       <a href='vscode-notebook-cell:/c%3A/final%20project/code.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a> df_t4=data.sort_values(by='cons.price.idx', ascending=False,ignore_index=True)
# ----> <a href='vscode-notebook-cell:/c%3A/final%20project/code.ipynb#X36sZmlsZQ%3D%3D?line=2'>3</a> df_t4.data['cons.price.idx'].plot(ax=ax)
#
# File c:\conda\envs\ds\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
# ...

# %%
d1=data[['cons.price.idx','y']]

# %%
age=bank_data.groupby(["age","y"],as_index=False).sum()
fig, ax = plt.subplots()
age.bar.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\final project\code.ipynb Cell 26 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/final%20project/code.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> age=bank_data.groupby(["age","y"],as_index=False).sum()
#       <a href='vscode-notebook-cell:/c%3A/final%20project/code.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> fig, ax = plt.subplots()
#       <a href='vscode-notebook-cell:/c%3A/final%20project/code.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a> age.bar.plot()
#
# File c:\conda\envs\ds\lib\site-packages\pandas\core\series.py:1922, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1918 axis = self._get_axis_number(axis)
#    1920 # error: Argument "squeeze" to "SeriesGroupBy" has incompatible type
#    1921 # "Union[bool, NoDefault]"; expected "bool"
# -> 1922 return SeriesGroupBy(
# ...

# %%
data.hist(bins = 15, figsize = (10,10), xlabelsize = 0.1, ylabelsize = 0.1)
plt.show()

# %%
data.plot.box( figsize = (10,10))
plt.show()

# %%
pd.plotting.scatter_matrix(data, figsize=(25,25))
# Out:
# c:\conda\envs\ds\lib\site-packages\pandas\plotting\_matplotlib\misc.py:100: UserWarning: Attempting to set identical left == right == 1.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# c:\conda\envs\ds\lib\site-packages\pandas\plotting\_matplotlib\misc.py:101: UserWarning: Attempting to set identical bottom == top == 1.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# c:\conda\envs\ds\lib\site-packages\pandas\plotting\_matplotlib\misc.py:91: UserWarning: Attempting to set identical left == right == 1.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])
# array([[<AxesSubplot:xlabel='age', ylabel='age'>,
#         <AxesSubplot:xlabel='duration', ylabel='age'>,
#         <AxesSubplot:xlabel='campaign', ylabel='age'>,
#         <AxesSubplot:xlabel='pdays', ylabel='age'>,
#         <AxesSubplot:xlabel='previous', ylabel='age'>,
# ...

# %%
def plot_bar(column):
    # temp df 
    temp_1 = pd.DataFrame()
    # count categorical values
    temp_1['No_deposit'] = data[data['y'] == 'no'][column].value_counts()
    temp_1['Yes_deposit'] = data[data['y'] == 'yes'][column].value_counts()
    temp_1.plot(kind='bar')
    plt.xlabel(f'{column}')
    plt.ylabel('Number of clients')
    plt.title('Distribution of {} and deposit'.format(column))
    plt.show();
plot_bar('job'), plot_bar('marital'), plot_bar('education'), plot_bar('contact'), plot_bar('loan'), plot_bar('housing')
# Out:
# (None, None, None, None, None, None)
